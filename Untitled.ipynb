# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import requests
from prefect import task, flow
from dotenv import load_dotenv

# โหลดตัวแปรจากไฟล์ .env
load_dotenv()

# เช็กว่ารันอยู่ใน Docker หรือไม่เพื่อเลือก Host ที่ถูกต้อง
DB_HOST = "postgres_dw" if os.getenv("IN_DOCKER") else "localhost"
DB_USER = os.getenv("POSTGRES_USER")
DB_PASS = os.getenv("POSTGRES_PASSWORD")
DB_NAME = os.getenv("POSTGRES_DB")
# ถ้าไม่มี POSTGRES_PORT ใน .env จะใช้ 5435 เป็นค่า Default
DB_PORT = "5432" if os.getenv("IN_DOCKER") else os.getenv("POSTGRES_PORT", "5435")

# แนะนำให้ใส่ +psycopg2 เพื่อความเสถียรของ SQLAlchemy
PG_URI = f"postgresql+psycopg2://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"

@task(log_prints=True, retries=3)
def download_db():
    sources = {
        "chinook.db": "https://raw.githubusercontent.com/lerocha/chinook-database/master/ChinookDatabase/DataSources/Chinook_Sqlite.sqlite",
        "northwind.db": "https://github.com/jpwhite3/northwind-SQLite3/raw/main/dist/northwind.db"
    }
    for name, url in sources.items():
        if not os.path.exists(name):
            print(f"📥 Downloading {name}...")
            r = requests.get(url)
            with open(name, "wb") as f:
                f.write(r.content)
        else:
            print(f"✅ {name} already exists.")
    return list(sources.keys())

@task(log_prints=True)
def etl_task(db_file, tables, prefix):
    # ใช้ Absolute Path เพื่อให้ SQLAlchemy หาไฟล์เจอเสมอไม่ว่าจะรันจาก Path ไหน
    db_path = os.path.abspath(db_file)
    src_engine = create_engine(f"sqlite:///{db_path}")
    target_engine = create_engine(PG_URI)
    
    for table in tables:
        print(f"⏳ Extracting {table} from {db_file}...")
        df = pd.read_sql(f'SELECT * FROM "{table}"', src_engine)
        
        # Clean ข้อมูลเบื้องต้น: คอลัมน์ตัวเล็ก, ไม่มีช่องว่าง
        df.columns = [c.lower().replace(' ', '_') for c in df.columns]
        
        # แปลงข้อมูลวันที่ให้เป็น Datetime (สำคัญมากสำหรับการทำ Dashboard ใน Metabase)
        for col in df.columns:
            if 'date' in col.lower() or 'time' in col.lower():
                df[col] = pd.to_datetime(df[col], errors='coerce')
                
        target_name = f"{prefix}_{table.lower().replace(' ', '_')}"
        df.to_sql(target_name, target_engine, if_exists="replace", index=False)
        print(f"✅ {target_name} loaded: {len(df)} rows")

@flow(name="End-to-End Data Pipeline")
def main_flow():
    # 1. โหลดฐานข้อมูล
    download_db()
    
    # 2. จัดการย้าย Northwind
    nw_tables = ["Orders", "Order Details", "Products", "Customers"]
    etl_task("northwind.db", nw_tables, "nw")
    
    # 3. จัดการย้าย Chinook
    cnk_tables = ["Invoice", "Track", "Customer", "Artist"]
    etl_task("chinook.db", cnk_tables, "cnk")

if __name__ == "__main__":
    main_flow()
# Out:
# 01:31:49.809 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8902
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 01:31:53.677 | INFO    | Flow run 'zealous-cockle' - Beginning flow run 'zealous-cockle' for flow 'End-to-End Data Pipeline'
# 01:31:53.708 | INFO    | Task run 'download_db-420' - 📥 Downloading chinook.db...
# 01:31:54.204 | INFO    | Task run 'download_db-420' - 📥 Downloading northwind.db...
# 01:31:57.240 | INFO    | Task run 'download_db-420' - Finished in state Completed()
# 01:31:57.269 | ERROR   | Task run 'etl_task-5bc' - Task run failed with exception: ModuleNotFoundError("No module named 'psycopg2'")
# Traceback (most recent call last):
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1014, in run_context
#     yield self
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/utilities/callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "/var/folders/ct/2csm1_v52qg6knfp18g5gb8w0000gn/T/ipykernel_15195/384435632.py", line 43, in etl_task
#     target_engine = create_engine(PG_URI)
#   File "<string>", line 2, in create_engine
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py", line 696, in import_dbapi
#     import psycopg2
# ModuleNotFoundError: No module named 'psycopg2'
# 01:31:57.282 | ERROR   | Task run 'etl_task-5bc' - Finished in state Failed("Task run encountered an exception ModuleNotFoundError: No module named 'psycopg2'")
# 01:31:57.709 | ERROR   | Flow run 'zealous-cockle' - Encountered exception during execution: ModuleNotFoundError("No module named 'psycopg2'")
# Traceback (most recent call last):
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py", line 988, in run_context
#     yield self
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py", line 1633, in run_flow_sync
#     engine.call_flow_fn()
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py", line 1008, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/utilities/callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "/var/folders/ct/2csm1_v52qg6knfp18g5gb8w0000gn/T/ipykernel_15195/384435632.py", line 68, in main_flow
#     etl_task("northwind.db", nw_tables, "nw")
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/tasks.py", line 1209, in __call__
#     return run_task(
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1900, in run_task
#     return run_task_sync(**kwargs)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1675, in run_task_sync
#     return engine.state if return_type == "state" else engine.result()
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 611, in result
#     raise self._raised
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1014, in run_context
#     yield self
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1673, in run_task_sync
#     engine.call_task_fn(txn)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py", line 1031, in call_task_fn
#     result = call_with_parameters(self.task.fn, parameters)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/utilities/callables.py", line 210, in call_with_parameters
#     return fn(*args, **kwargs)
#   File "/var/folders/ct/2csm1_v52qg6knfp18g5gb8w0000gn/T/ipykernel_15195/384435632.py", line 43, in etl_task
#     target_engine = create_engine(PG_URI)
#   File "<string>", line 2, in create_engine
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py", line 617, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "/Users/palmchns/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py", line 696, in import_dbapi
#     import psycopg2
# ModuleNotFoundError: No module named 'psycopg2'
# 01:31:57.782 | INFO    | Flow run 'zealous-cockle' - Finished in state Failed("Flow run encountered an exception: ModuleNotFoundError: No module named 'psycopg2'")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 75
#      72     etl_task("chinook.db", cnk_tables, "cnk")
#      74 if __name__ == "__main__":
# ---> 75     main_flow()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flows.py:1876, in Flow.__call__(self, return_state, wait_for, *args, **kwargs)
#    1872     return track_viz_task(self.isasync, self.name, parameters)
#    1874 from prefect.flow_engine import run_flow
# -> 1876 return run_flow(
#    1877     flow=self,
#    1878     parameters=parameters,
#    1879     wait_for=wait_for,
#    1880     return_type=return_type,
#    1881 )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:1790, in run_flow(flow, flow_run, parameters, wait_for, return_type, error_logger, context)
#    1788         ret_val = run_flow_async(**kwargs)
#    1789     else:
# -> 1790         ret_val = run_flow_sync(**kwargs)
#    1791 except (Abort, Pause):
#    1792     raise
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:1635, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type, context)
#    1632         with engine.run_context():
#    1633             engine.call_flow_fn()
# -> 1635 return engine.state if return_type == "state" else engine.result()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:538, in FlowRunEngine.result(self, raise_on_failure)
#     536 if self._raised is not NotSet:
#     537     if raise_on_failure:
# --> 538         raise self._raised
#     539     return self._raised
#     541 # This is a fall through case which leans on the existing state result mechanics to get the
#     542 # return value. This is necessary because we currently will return a State object if the
#     543 # the State was Prefect-created.
#     544 # TODO: Remove the need to get the result from a State except in cases where the return value
#     545 # is a State object.
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:988, in FlowRunEngine.run_context(self)
#     984         with _send_heartbeats(self):
#     985             self.logger.debug(
#     986                 f"Executing flow {self.flow.name!r} for flow run {self.flow_run.name!r}..."
#     987             )
# --> 988             yield self
#     989 except TimeoutError as exc:
#     990     self.handle_timeout(exc)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:1633, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type, context)
#    1631     while engine.is_running():
#    1632         with engine.run_context():
# -> 1633             engine.call_flow_fn()
#    1635 return engine.state if return_type == "state" else engine.result()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/flow_engine.py:1008, in FlowRunEngine.call_flow_fn(self)
#    1006     return _call_flow_fn()
#    1007 else:
# -> 1008     result = call_with_parameters(self.flow.fn, self.parameters)
#    1009     self.handle_success(result)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/utilities/callables.py:210, in call_with_parameters(fn, parameters)
#     202 """
#     203 Call a function with parameters extracted with `get_call_parameters`
#     204
#    (...)
#     207 the args/kwargs using `parameters_to_positional_and_keyword` directly
#     208 """
#     209 args, kwargs = parameters_to_args_kwargs(fn, parameters)
# --> 210 return fn(*args, **kwargs)
#
# Cell In[1], line 68, in main_flow()
#      66 # 2. จัดการย้าย Northwind
#      67 nw_tables = ["Orders", "Order Details", "Products", "Customers"]
# ---> 68 etl_task("northwind.db", nw_tables, "nw")
#      70 # 3. จัดการย้าย Chinook
#      71 cnk_tables = ["Invoice", "Track", "Customer", "Artist"]
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/tasks.py:1209, in Task.__call__(self, return_state, wait_for, *args, **kwargs)
#    1203     return track_viz_task(
#    1204         self.isasync, self.name, parameters, self.viz_return_value
#    1205     )
#    1207 from prefect.task_engine import run_task
# -> 1209 return run_task(
#    1210     task=self,
#    1211     parameters=parameters,
#    1212     wait_for=wait_for,
#    1213     return_type=return_type,
#    1214 )
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:1900, in run_task(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1898     return run_task_async(**kwargs)
#    1899 else:
# -> 1900     return run_task_sync(**kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:1675, in run_task_sync(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1668         with (
#    1669             engine.asset_context(),
#    1670             engine.run_context(),
#    1671             engine.transaction_context() as txn,
#    1672         ):
#    1673             engine.call_task_fn(txn)
# -> 1675 return engine.state if return_type == "state" else engine.result()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:611, in SyncTaskRunEngine.result(self, raise_on_failure)
#     608 if self._raised is not NotSet:
#     609     # if the task raised an exception, raise it
#     610     if raise_on_failure:
# --> 611         raise self._raised
#     613     # otherwise, return the exception
#     614     return self._raised
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:1014, in SyncTaskRunEngine.run_context(self)
#    1011         if self.is_cancelled():
#    1012             raise CancelledError("Task run cancelled by the task runner")
# -> 1014         yield self
#    1015 except TimeoutError as exc:
#    1016     self.handle_timeout(exc)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:1673, in run_task_sync(task, task_run_id, task_run, parameters, wait_for, return_type, dependencies, context)
#    1667         engine.wait_until_ready()
#    1668         with (
#    1669             engine.asset_context(),
#    1670             engine.run_context(),
#    1671             engine.transaction_context() as txn,
#    1672         ):
# -> 1673             engine.call_task_fn(txn)
#    1675 return engine.state if return_type == "state" else engine.result()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/task_engine.py:1031, in SyncTaskRunEngine.call_task_fn(self, transaction)
#    1029     result = transaction.read()
#    1030 else:
# -> 1031     result = call_with_parameters(self.task.fn, parameters)
#    1032 self.handle_success(result, transaction=transaction)
#    1033 return result
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/prefect/utilities/callables.py:210, in call_with_parameters(fn, parameters)
#     202 """
#     203 Call a function with parameters extracted with `get_call_parameters`
#     204
#    (...)
#     207 the args/kwargs using `parameters_to_positional_and_keyword` directly
#     208 """
#     209 args, kwargs = parameters_to_args_kwargs(fn, parameters)
# --> 210 return fn(*args, **kwargs)
#
# Cell In[1], line 43, in etl_task(db_file, tables, prefix)
#      41 db_path = os.path.abspath(db_file)
#      42 src_engine = create_engine(f"sqlite:///{db_path}")
# ---> 43 target_engine = create_engine(PG_URI)
#      45 for table in tables:
#      46     print(f"⏳ Extracting {table} from {db_file}...")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/engine/create.py:617, in create_engine(url, **kwargs)
#     615         if k in kwargs:
#     616             dbapi_args[k] = pop_kwarg(k)
# --> 617     dbapi = dbapi_meth(**dbapi_args)
#     619 dialect_args["dbapi"] = dbapi
#     621 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:696, in PGDialect_psycopg2.import_dbapi(cls)
#     694 @classmethod
#     695 def import_dbapi(cls):
# --> 696     import psycopg2
#     698     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'
